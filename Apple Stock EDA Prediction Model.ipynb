# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('AAPL_daily_data.csv')
df
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091630
# ...           ...         ...         ...         ...         ...         ...
# 11035  2024-09-23  227.339996  229.449997  225.809998  226.470001  226.470001
# 11036  2024-09-24  228.649994  229.350006  225.729996  227.369995  227.369995
# 11037  2024-09-25  224.929993  227.289993  224.020004  226.369995  226.369995
# 11038  2024-09-26  227.300003  228.500000  225.410004  227.520004  227.520004
# 11039  2024-09-27  228.460007  229.520004  227.300003  227.789993  227.789993
#
#           Volume
# 0      469033600
# 1      175884800
# 2      105728000
# 3       86441600
# 4       73449600
# ...          ...
# 11035   54146000
# 11036   43556100
# 11037   42308700
# 11038   36636700
# 11039   34026000
#
# [11040 rows x 7 columns]

# %%
df.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
# 5  1980-12-19  0.126116  0.126674  0.126116  0.126116   0.097223   48630400
# 6  1980-12-22  0.132254  0.132813  0.132254  0.132254   0.101954   37363200
# 7  1980-12-23  0.137835  0.138393  0.137835  0.137835   0.106257   46950400
# 8  1980-12-24  0.145089  0.145647  0.145089  0.145089   0.111849   48003200
# 9  1980-12-26  0.158482  0.159040  0.158482  0.158482   0.122173   55574400

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  11040.000000  11040.000000  11040.000000  11040.000000  11040.000000
# mean      23.058766     23.306969     22.820680     23.073909     22.258584
# std       47.534929     48.043691     47.058335     47.573507     47.127496
# min        0.049665      0.049665      0.049107      0.049107      0.037856
# 25%        0.299107      0.305329      0.291964      0.299107      0.242593
# 50%        0.535714      0.542411      0.526786      0.535714      0.435984
# 75%       20.567054     20.736965     20.371071     20.542500     17.556267
# max      236.479996    237.229996    233.089996    234.820007    234.548523
#
#              Volume
# count  1.104000e+04
# mean   3.170834e+08
# std    3.352135e+08
# min    0.000000e+00
# 25%    1.124505e+08
# 50%    2.048452e+08
# 75%    3.978450e+08
# max    7.421641e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11040 entries, 0 to 11039
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       11040 non-null  object
#  1   Open       11040 non-null  float64
#  2   High       11040 non-null  float64
#  3   Low        11040 non-null  float64
#  4   Close      11040 non-null  float64
#  5   Adj Close  11040 non-null  float64
#  6   Volume     11040 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 603.9+ KB

# %%
df.shape
# Out:
# (11040, 7)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Date         11040
# Open          6346
# High          6291
# Low           6279
# Close         6455
# Adj Close     8031
# Volume       10476
# dtype: int64

# %%
data_types = df.dtypes
data_types
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df.describe(include='all')
# Out:
#               Date          Open          High           Low         Close  \
# count        11040  11040.000000  11040.000000  11040.000000  11040.000000
# unique       11040           NaN           NaN           NaN           NaN
# top     1980-12-12           NaN           NaN           NaN           NaN
# freq             1           NaN           NaN           NaN           NaN
# mean           NaN     23.058766     23.306969     22.820680     23.073909
# std            NaN     47.534929     48.043691     47.058335     47.573507
# min            NaN      0.049665      0.049665      0.049107      0.049107
# 25%            NaN      0.299107      0.305329      0.291964      0.299107
# 50%            NaN      0.535714      0.542411      0.526786      0.535714
# 75%            NaN     20.567054     20.736965     20.371071     20.542500
# max            NaN    236.479996    237.229996    233.089996    234.820007
#
#            Adj Close        Volume
# count   11040.000000  1.104000e+04
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean       22.258584  3.170834e+08
# std        47.127496  3.352135e+08
# min         0.037856  0.000000e+00
# 25%         0.242593  1.124505e+08
# 50%         0.435984  2.048452e+08
# 75%        17.556267  3.978450e+08
# max       234.548523  7.421641e+09

# %% [markdown]
# Removing Outliers Using Z-Scores

# %%
from scipy import stats

z_scores = stats.zscore(df.select_dtypes(include=['float64', 'int64']))
z_scores
# Out:
#            Open      High       Low     Close  Adj Close    Volume
# 0     -0.482413 -0.482459 -0.482239 -0.482340  -0.470227  0.453314
# 1     -0.482542 -0.482598 -0.482381 -0.482481  -0.470337 -0.421239
# 2     -0.482730 -0.482784 -0.482571 -0.482668  -0.470483 -0.630538
# 3     -0.482683 -0.482726 -0.482512 -0.482610  -0.470437 -0.688076
# 4     -0.482612 -0.482656 -0.482440 -0.482539  -0.470383 -0.726835
# ...         ...       ...       ...       ...        ...       ...
# 11035  4.297692  4.290935  4.313763  4.275600   4.333366 -0.784423
# 11036  4.325252  4.288854  4.312063  4.294519   4.352463 -0.816016
# 11037  4.246990  4.245974  4.275724  4.273498   4.331243 -0.819738
# 11038  4.296851  4.271161  4.305263  4.297673   4.355647 -0.836659
# 11039  4.321255  4.292392  4.345427  4.303348   4.361376 -0.844448
#
# [11040 rows x 6 columns]

# %%
df_outliers = df[(z_scores > 3).any(axis=1) | (z_scores < -3).any(axis=1)]
print(f"The number of outlier rows: {df_outliers.shape[0]}")
# Out:
# The number of outlier rows: 666

# %%
df_no_outliers = df[(z_scores < 3).all(axis=1) & (z_scores > -3).all(axis=1)]
print(f"Number of rows after outlier removal: {df_no_outliers.shape[0]}")
# Out:
# Number of rows after outlier removal: 10374

# %% [markdown]
# Min & Max Values of Close Price & Volume Traded

# %%
df['Close'].min()
# Out:
# 0.0491070002317428

# %%
df[df['Close']==df['Close'].min()]
# Out:
#            Date      Open      High       Low     Close  Adj Close     Volume
# 395  1982-07-08  0.049665  0.049665  0.049107  0.049107   0.037856  164326400

# %%
df[df['Close']==df['Close'].max()]
# Out:
#              Date   Open        High         Low       Close   Adj Close  \
# 10987  2024-07-16  235.0  236.270004  232.330002  234.820007  234.548523
#
#          Volume
# 10987  43234300

# %%
df[df['Volume']==df['Volume'].min()]
# Out:
#            Date      Open      High       Low     Close  Adj Close  Volume
# 165  1981-08-10  0.112723  0.112723  0.112723  0.112723   0.086898       0

# %%
df[df['Volume']==df['Volume'].max()]
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 5004  2000-09-29  0.503348  0.517857  0.453125  0.459821   0.388307
#
#           Volume
# 5004  7421640800

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Box Plots

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Close'], color='grey')

plt.title('Box Plot of Closing Price', fontsize=16)
plt.xlabel('Closing Price', fontsize=14)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Volume'], color='orange')

plt.title('Box Plot of Volume Traded', fontsize=16)
plt.xlabel('Volume Traded in the Day', fontsize=14)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['High'], color='teal')

plt.title('Box Plot of Highest Price', fontsize=16)
plt.xlabel('Highest Price of the Day', fontsize=14)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Low'], color='khaki')

plt.title('Box Plot of Lowest Price', fontsize=16)
plt.xlabel('Lowest Price of the Day', fontsize=14)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Open'], color='yellowgreen')

plt.title('Box Plot of Opening Price', fontsize=16)
plt.xlabel('Opening Price of the Day', fontsize=14)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Adj Close'], color='turquoise')

plt.title('Box Plot of Adjusted Close', fontsize=16)
plt.xlabel('Adjusted Close', fontsize=14)

plt.show()

# %% [markdown]
# Joint Plot of Closing Price & Volume Traded

# %%
sns.jointplot(x='Volume', y='Close', data=df_no_outliers, color='teal')
plt.suptitle('Joint Plot of Closing Price and Volume Traded', y=1.02)
plt.show()

# %% [markdown]
# Destiny Plots

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(data=df, x='Volume', shade=True, color='gold')
plt.title('Density Plot of Volume')
plt.xlabel('Volume')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(data=df, x='Close', shade=True, color='silver')
plt.title('Density Plot of Closing Price')
plt.xlabel('Closing Price')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# Regression Plot of Closing Price vs. Volume

# %%
plt.figure(figsize=(10,6))
sns.regplot(x='Volume', y='Close', data=df_no_outliers, scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title('Closing Price vs. Volume')
plt.xlabel('Volume')
plt.ylabel('Closing Price')
plt.show()

# %% [markdown]
# Closing Price (USD) vs. Date of Apple Stock

# %%
df['Date']= pd.to_datetime(df['Date'])
plt.figure(figsize=(10,6))
plt.plot(df['Date'], df['Close'], label='APPLE', color='grey')
plt.title('Stock Price of Apple Inc.', fontsize=19)
plt.xlabel('Date', fontsize=16)
plt.ylabel('Closing Price (USD)', fontsize=16)

plt.xticks(rotation=45)
plt.legend(loc='upper left', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# Volume Traded Over TIme

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Volume'], label='Volume', color='orange')
plt.title('Volume Traded Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Distribution of Open Price, Close Price & Adjusted Close Price

# %%
# Distribution of Stock Prices (Open, Close, Adj Close)
plt.figure(figsize=(14, 8))

# Plot Open price distribution
plt.subplot(3, 1, 1)
sns.histplot(df['Open'], kde=True, color='blue', bins=30)
plt.title('Distribution of Open Price', fontsize=14)
plt.xlabel('Price (USD)', fontsize=12)

# Plot Close price distribution
plt.subplot(3, 1, 2)
sns.histplot(df['Close'], kde=True, color='green', bins=30)
plt.title('Distribution of Close Price', fontsize=14)
plt.xlabel('Price (USD)', fontsize=12)

# Plot Adjusted Close price distribution
plt.subplot(3, 1, 3)
sns.histplot(df['Adj Close'], kde=True, color='red', bins=30)
plt.title('Distribution of Adjusted Close Price', fontsize=14)
plt.xlabel('Price (USD)', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# Stock Price with 30-day and 100-day Moving Averages

# %%
df['MA30'] = df['Close'].rolling(window=30).mean()
df['MA100'] = df['Close'].rolling(window=100).mean()

plt.figure(figsize=(14, 8))
plt.plot(df['Date'], df['Close'], label='Close Price', color='blue', alpha=0.6)
plt.plot(df['Date'], df['MA30'], label='30-day Moving Average', color='green', linestyle='--')
plt.plot(df['Date'], df['MA100'], label='100-day Moving Average', color='red', linestyle='--')
plt.title('Stock Price with 30-day and 100-day Moving Averages', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price (USD)', fontsize=12)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
correlation_matrix = df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']].corr()

plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', linewidths=0.5, fmt='.2f')
plt.title('Correlation Matrix for Stock Prices and Volume for APPLE',fontsize=16)
plt.show()

# %%
sns.pairplot(df)

# %%
sns.pairplot(df_no_outliers)

# %% [markdown]
# Prediction Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score

# %%
df.isna().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Adj Close     0
# Volume        0
# MA30         29
# MA100        99
# dtype: int64

# %%
features = df.drop(columns=['Date', 'Close', 'MA30', 'MA100'])
target = df['Close']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=29)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

rf_model = RandomForestRegressor(n_estimators=250, random_state=29)

rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(n_estimators=250, random_state=29)

# %%
y_pred_rf = rf_model.predict(X_test_scaled)

y_pred_rf
# Out:
# array([  0.26917107,   3.14042859,   0.24720447, ...,   0.34025818,
#        165.11196417, 194.41756091])

# %%
y_test
# Out:
# 3395       0.273438
# 7118       3.140714
# 2476       0.258929
# 8224      14.963929
# 2588       0.566964
#             ...
# 10633    155.330002
# 524        0.128348
# 5277       0.340536
# 10390    165.119995
# 10869    194.169998
# Name: Close, Length: 2208, dtype: float64

# %%
mae_rf = mean_absolute_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

mae_rf, r2_rf
# Out:
# (0.07361759402174357, 0.9999829134359948)

# %%
mean_closing_price = df['Close'].mean()
mean_closing_price
# Out:
# 23.073908789421136

# %%
error_percent = (mae_rf/mean_closing_price)*100
error_percent
# Out:
# 0.3190512482891307

# %%
percentage_accuracy_of_closing_price = 100-error_percent
percentage_accuracy_of_closing_price
# Out:
# 99.68094875171087
